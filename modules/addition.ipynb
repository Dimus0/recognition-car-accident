# %%
import pandas as pd

df = pd.read_csv(r"E:\car_image_dataset\ltsm_dataset\model_train\train\data\1.csv",sep=",")
df.head(10)
# Out:
#       TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 0  3.159715e+08  00000000-0000-0000-0000-000000000000          AV
# 1  3.159715e+08  00000000-0000-0000-0000-000000070303      OTHERS
# 2  3.159715e+08  00000000-0000-0000-0000-000000070324       AGENT
# 3  3.159715e+08  00000000-0000-0000-0000-000000070377      OTHERS
# 4  3.159715e+08  00000000-0000-0000-0000-000000070506      OTHERS
# 5  3.159715e+08  00000000-0000-0000-0000-000000070503      OTHERS
# 6  3.159715e+08  00000000-0000-0000-0000-000000070502      OTHERS
# 7  3.159715e+08  00000000-0000-0000-0000-000000070414      OTHERS
# 8  3.159715e+08  00000000-0000-0000-0000-000000070500      OTHERS
# 9  3.159715e+08  00000000-0000-0000-0000-000000000000          AV
#
#              X            Y CITY_NAME
# 0  2661.015638  1145.753052       PIT
# 1  2647.091877  1133.773471       PIT
# 2  2687.072647  1170.677285       PIT
# 3  2628.763395  1116.403241       PIT
# 4  2600.212736  1175.594186       PIT
# ...

# %%
df['OBJECT_TYPE'].unique()
# Out:
# array(['AV', 'OTHERS', 'AGENT'], dtype=object)
